# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\shaur\OneDrive\Desktop\0 Machine Learning\imdb_clean2.csv",index_col=0)

# %%
df
# Out:
#                         title  release_year  runtime   genre  rating  \
# 0    The Shawshank Redemption          1994      142   Drama     9.3
# 1               The Godfather          1972      175   Crime     9.2
# 1               The Godfather          1972      175   Drama     9.2
# 2             The Dark Knight          2008      152  Action     9.0
# 2             The Dark Knight          2008      152   Crime     9.0
# ..                        ...           ...      ...     ...     ...
# 998         The Invisible Man          1933       71  Horror     7.6
# 998         The Invisible Man          1933       71  Sci-Fi     7.6
# 999                  Cell 211          2009      113  Action     7.6
# 999                  Cell 211          2009      113   Crime     7.6
# 999                  Cell 211          2009      113   Drama     7.6
#
#      metascore  gross(M)
# 0           82     28.34
# 1          100    134.97
# 1          100    134.97
# 2           84    534.86
# ...

# %%
df.dtypes
# Out:
# title            object
# release_year      int64
# runtime           int64
# genre            object
# rating          float64
# metascore         int64
# gross(M)        float64
# dtype: object

# %%
df.describe()
# Out:
#        release_year      runtime       rating    metascore     gross(M)
# count   2532.000000  2532.000000  2532.000000  2532.000000  2532.000000
# mean    1992.241706   124.209716     7.966272    66.547393    61.718515
# std       24.221845    28.915958     0.274463    30.463166   113.378029
# min     1920.000000    45.000000     7.600000     0.000000     0.000000
# 25%     1976.000000   103.000000     7.800000    64.000000     0.287500
# 50%     2000.000000   120.000000     7.900000    76.000000    10.775000
# 75%     2011.000000   139.000000     8.100000    86.000000    70.100000
# max     2023.000000   321.000000     9.300000   100.000000   936.660000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2532 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         2532 non-null   object
#  1   release_year  2532 non-null   int64
#  2   runtime       2532 non-null   int64
#  3   genre         2532 non-null   object
#  4   rating        2532 non-null   float64
#  5   metascore     2532 non-null   int64
#  6   gross(M)      2532 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 158.2+ KB

# %%
df.isnull().sum()
# Out:
# title           0
# release_year    0
# runtime         0
# genre           0
# rating          0
# metascore       0
# gross(M)        0
# dtype: int64

# %%
df.corr()
# Out:
#                                  release_year  runtime  rating  metascore  \
# title        genre
# 12 Angry Men Crime release_year           NaN      NaN     NaN        NaN
#                    runtime                NaN      NaN     NaN        NaN
#                    rating                 NaN      NaN     NaN        NaN
#                    metascore              NaN      NaN     NaN        NaN
#                    gross(M)               NaN      NaN     NaN        NaN
# ...                                       ...      ...     ...        ...
# Zulu         War   release_year           NaN      NaN     NaN        NaN
#                    runtime                NaN      NaN     NaN        NaN
#                    rating                 NaN      NaN     NaN        NaN
#                    metascore              NaN      NaN     NaN        NaN
#                    gross(M)               NaN      NaN     NaN        NaN
#
#                                  gross(M)
# ...

# %%
df['release_year'].unique()
# Out:
# title         genre
# 12 Angry Men  Crime        [1957]
#               Drama        [1957]
# 12 Monkeys    Mystery      [1995]
#               Sci-Fi       [1995]
#               Thriller     [1995]
#                             ...
# Zootopia      Animation    [2016]
#               Comedy       [2016]
# Zulu          Drama        [1964]
#               History      [1964]
#               War          [1964]
# Name: release_year, Length: 2520, dtype: object

# %%
df.columns
# Out:
# Index(['title', 'release_year', 'runtime', 'genre', 'rating', 'metascore',
#        'gross(M)'],
#       dtype='object')

# %%
df[['release_year', 'title', 'genre']]
# Out:
#      release_year                     title   genre
# 0            1994  The Shawshank Redemption   Drama
# 1            1972             The Godfather   Crime
# 1            1972             The Godfather   Drama
# 2            2008           The Dark Knight  Action
# 2            2008           The Dark Knight   Crime
# ..            ...                       ...     ...
# 998          1933         The Invisible Man  Horror
# 998          1933         The Invisible Man  Sci-Fi
# 999          2009                  Cell 211  Action
# 999          2009                  Cell 211   Crime
# 999          2009                  Cell 211   Drama
#
# [2532 rows x 3 columns]

# %%
df[(df['rating'] > 7) & (df['release_year'] >= 1985) & (df['genre']== 'Drama')]
# Out:
#                                              title  release_year  runtime  \
# 0                         The Shawshank Redemption          1994      142
# 2                                  The Dark Knight          2008      152
# 3                                 Schindler's List          1993      195
# 6    The Lord of the Rings: The Return of the King          2003      201
# 8                                     Pulp Fiction          1994      154
# ..                                             ...           ...      ...
# 994                                          Shine          1996      105
# 995                                      Philomena          2013       98
# 996                                        Control          2007      122
# 997                         A Very Long Engagement          2004      133
# 999                                       Cell 211          2009      113
#
#      genre  rating  metascore  gross(M)
# ...

# %%
df[(df['rating'] > 8.5) & (df['release_year'] >= 2000)]
# Out:
#                                                 title  release_year  runtime  \
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 6       The Lord of the Rings: The Return of the King          2003      201
# 6       The Lord of the Rings: The Return of the King          2003      201
# 6       The Lord of the Rings: The Return of the King          2003      201
# 7                 Spider-Man: Across the Spider-Verse          2023      140
# 7                 Spider-Man: Across the Spider-Verse          2023      140
# 7                 Spider-Man: Across the Spider-Verse          2023      140
# 9                                           Inception          2010      148
# 9                                           Inception          2010      148
# ...

# %%
df[(df['rating'] > 8.7)]
# Out:
#                                                 title  release_year  runtime  \
# 0                            The Shawshank Redemption          1994      142
# 1                                       The Godfather          1972      175
# 1                                       The Godfather          1972      175
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 3                                    Schindler's List          1993      195
# 3                                    Schindler's List          1993      195
# 3                                    Schindler's List          1993      195
# 4                                        12 Angry Men          1957       96
# 4                                        12 Angry Men          1957       96
# ...

# %%
df[(df['release_year'] > 2000)]
# Out:
#                                              title  release_year  runtime  \
# 2                                  The Dark Knight          2008      152
# 2                                  The Dark Knight          2008      152
# 2                                  The Dark Knight          2008      152
# 6    The Lord of the Rings: The Return of the King          2003      201
# 6    The Lord of the Rings: The Return of the King          2003      201
# ..                                             ...           ...      ...
# 997                         A Very Long Engagement          2004      133
# 997                         A Very Long Engagement          2004      133
# 999                                       Cell 211          2009      113
# 999                                       Cell 211          2009      113
# 999                                       Cell 211          2009      113
#
#          genre  rating  metascore  gross(M)
# ...

# %%
df[(df['runtime'] < 105 ) & (df['metascore'] >= 80)]
df.head(30)
# Out:
#                                                 title  release_year  runtime  \
# 0                            The Shawshank Redemption          1994      142
# 1                                       The Godfather          1972      175
# 1                                       The Godfather          1972      175
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 2                                     The Dark Knight          2008      152
# 3                                    Schindler's List          1993      195
# 3                                    Schindler's List          1993      195
# 3                                    Schindler's List          1993      195
# 4                                        12 Angry Men          1957       96
# 4                                        12 Angry Men          1957       96
# ...
